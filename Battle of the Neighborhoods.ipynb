# %% [markdown]
# # Venues Types in High COVID-19 Rate Iowa Counties

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Is there a difference in venue type and venue volumes in Iowa counties with high covid rates compared to those with low covid rates?
#
# I will be exploring Iowa COVID-19 data at the county level in conjunction with venue data from FourSquare to determine any commanalities between counties with high & low positive COVID-19 rates. Iowa's govenor has been restricting hours of operations in certain business types. This analysis may pinpoint addition or different business types to target in order to stem the spread of the infection.

# %% [markdown]
# ## Data Needed

# %% [markdown]
# County level COVID-19 data for the state of Iowa in the United States.
#  * Obtained from NY Time git respository.
#   * https://github.com/nytimes/covid-19-data
#   * https://www.nytimes.com/interactive/2020/us/coronavirus-us-cases.html
#
# County level population data for the state of Iowa in the United States.
#  * US Census Bureau data access via Iowa State University's Iowa Community Indicator Program
#
# County level venue data for the state of Iowa in the United States.
#  * FourSquare

# %% [markdown]
# ### County-level COVID-19 Data for Iowa, United States

# %% [markdown]
# I am sourcing my COVID-19 data from the NY Times Github repository. Since late January the Times has been collecting data from state and local governments and health departments across the United States in an effort to provide an ongoing record of the outbreak.  They have made this data publically available.
#
# [The New York Times COVID Outbreak](https://www.nytimes.com/interactive/2020/us/coronavirus-us-cases.html)
#
# This data is provided with the fips code included (county detail code). This will help tie together population and venue data from other sources.
#
# While the dataset contains information from across the US, I will be focused on the state of Iowa.

# %%
#Import libraries:
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import json # library to handle JSON files
import requests # library to handle requests
from pandas import json_normalize # tranform JSON file into a pandas dataframe

# !pip install folium
#!conda install folium
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# !pip install geopy
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# !pip install geopandas

print('Libraries imported.')
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.11.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (0.4.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Requirement already satisfied: geopandas in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.8.1)
# Requirement already satisfied: pandas>=0.23.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopandas) (1.0.5)
# Requirement already satisfied: pyproj>=2.2.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopandas) (3.0.0.post1)
# Requirement already satisfied: shapely in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: fiona in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopandas) (1.8.18)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (1.18.5)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (2020.1)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pyproj>=2.2.0->geopandas) (2020.6.20)
# Requirement already satisfied: six>=1.7 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from fiona->geopandas) (1.15.0)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: munch in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from fiona->geopandas) (0.7.1)
# Requirement already satisfied: click<8,>=4.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from fiona->geopandas) (7.1.2)
# Requirement already satisfied: attrs>=17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from fiona->geopandas) (19.3.0)
# Libraries imported.

# %%
url = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv'
c19df = pd.read_csv(url, error_bad_lines=False)


c19df.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
print(c19df.dtypes)
# Out:
# date       object
# county     object
# state      object
# fips      float64
# cases       int64
# deaths      int64
# dtype: object

# %%
print(c19df.describe())
print(c19df.describe(include=['object']))
# Out:
#                 fips          cases         deaths
# count  744591.000000  751749.000000  751749.000000
# mean    31222.752582    1426.438910      45.459644
# std     16284.064649    7756.791436     430.349411
# min      1001.000000       0.000000       0.000000
# 25%     18177.000000      26.000000       0.000000
# 50%     29205.000000     149.000000       2.000000
# 75%     46095.000000     670.000000      15.000000
# max     78030.000000  357541.000000   24188.000000
#               date      county   state
# count       751749      751749  751749
# unique         305        1929      55
# top     2020-10-18  Washington   Texas
# freq          3248        7506   56588

# %%
iac19df = pd.DataFrame(c19df[c19df['state'] =='Iowa'])
iac19df.reset_index(drop=True,inplace=True)

# %%
iac19df.tail()
# Out:
#              date      county state     fips  cases  deaths
# 23165  2020-11-20   Winnebago  Iowa  19189.0    855      23
# 23166  2020-11-20  Winneshiek  Iowa  19191.0    860       9
# 23167  2020-11-20    Woodbury  Iowa  19193.0   9706     110
# 23168  2020-11-20       Worth  Iowa  19195.0    318       0
# 23169  2020-11-20      Wright  Iowa  19197.0   1118       5

# %%
print(iac19df.describe())
print(iac19df.describe(include=['object']))
# Out:
#                fips         cases        deaths
# count  22966.000000  23170.000000  23170.000000
# mean   19099.166681    561.095339      9.083211
# std       57.361880   1566.017872     25.148653
# min    19001.000000      0.000000      0.000000
# 25%    19049.000000     27.000000      0.000000
# 50%    19099.000000    125.000000      1.000000
# 75%    19149.000000    438.000000      7.000000
# max    19197.000000  30369.000000    319.000000
#               date   county  state
# count        23170    23170  23170
# unique         258      100      1
# top     2020-05-29  Johnson   Iowa
# freq           100      258  23170

# %% [markdown]
# ### County level population data for Iowa, United States

# %% [markdown]
# Iowa State University Iowa Community Indicators Program has cultivated population data for the State of Iowa from the US Census Bureau. This data contains annual population estimates at a county (fips) level.
#
# https://www.icip.iastate.edu/tables/population/counties-estimates
#
# I plan to use this data to assist in normalizing positive numbers/rates based upon the total population for the county.

# %%
url = 'https://www.icip.iastate.edu/sites/default/files/uploads/tables/population/popest-annual.xls'
xls=pd.ExcelFile(url)
pop_iacnty = pd.read_excel(xls, 'Counties', skiprows=[0,1,2,3,4,5])


pop_iacnty.head()
# Out:
#     Fips                    Area  Estimates Base (4/1/2010)       2010  \
# 0     19                    Iowa                  3046871.0  3050745.0
# 1  19001      Adair County, Iowa                     7682.0     7679.0
# 2  19003      Adams County, Iowa                     4029.0     4023.0
# 3  19005  Allamakee County, Iowa                    14328.0    14378.0
# 4  19007  Appanoose County, Iowa                    12887.0    12856.0
#
#         2011       2012       2013       2014       2015       2016  \
# 0  3066336.0  3076190.0  3092997.0  3109350.0  3120960.0  3131371.0
# 1     7546.0     7468.0     7387.0     7368.0     7145.0     7005.0
# 2     3994.0     3910.0     3891.0     3877.0     3754.0     3692.0
# 3    14222.0    14149.0    14071.0    14062.0    13874.0    13851.0
# 4    12848.0    12707.0    12654.0    12671.0    12577.0    12505.0
#
#         2017       2018       2019
# 0  3141550.0  3148618.0  3155070.0
# 1     7051.0     7074.0     7152.0
# 2     3657.0     3644.0     3602.0
# 3    13803.0    13852.0    13687.0
# 4    12353.0    12401.0    12426.0

# %%
print(pop_iacnty.dtypes)
# Out:
# Fips                          object
# Area                          object
# Estimates Base (4/1/2010)    float64
# 2010                         float64
# 2011                         float64
# 2012                         float64
# 2013                         float64
# 2014                         float64
# 2015                         float64
# 2016                         float64
# 2017                         float64
# 2018                         float64
# 2019                         float64
# dtype: object

# %%
total_ia = pd.DataFrame(pop_iacnty[pop_iacnty['Fips'] ==19])
pop_iacnty = pd.DataFrame(pop_iacnty[pop_iacnty['Fips'] !=19])
pop_iacnty.reset_index(drop=True,inplace=True)

# %%
total_ia.head()
# Out:
#   Fips  Area  Estimates Base (4/1/2010)       2010       2011       2012  \
# 0   19  Iowa                  3046871.0  3050745.0  3066336.0  3076190.0
#
#         2013       2014       2015       2016       2017       2018       2019
# 0  3092997.0  3109350.0  3120960.0  3131371.0  3141550.0  3148618.0  3155070.0

# %%
pop_iacnty.head()
# Out:
#     Fips                    Area  Estimates Base (4/1/2010)     2010     2011  \
# 0  19001      Adair County, Iowa                     7682.0   7679.0   7546.0
# 1  19003      Adams County, Iowa                     4029.0   4023.0   3994.0
# 2  19005  Allamakee County, Iowa                    14328.0  14378.0  14222.0
# 3  19007  Appanoose County, Iowa                    12887.0  12856.0  12848.0
# 4  19009    Audubon County, Iowa                     6119.0   6098.0   6004.0
#
#       2012     2013     2014     2015     2016     2017     2018     2019
# 0   7468.0   7387.0   7368.0   7145.0   7005.0   7051.0   7074.0   7152.0
# 1   3910.0   3891.0   3877.0   3754.0   3692.0   3657.0   3644.0   3602.0
# 2  14149.0  14071.0  14062.0  13874.0  13851.0  13803.0  13852.0  13687.0
# 3  12707.0  12654.0  12671.0  12577.0  12505.0  12353.0  12401.0  12426.0
# 4   5865.0   5863.0   5771.0   5711.0   5626.0   5550.0   5471.0   5496.0

# %% [markdown]
# ### FourSquare Venue Data

# %% [markdown]
# I am using FourSquare data to find venue types in each county to determine prevalent business types in Iowa counties.

# %%
# The code was removed by Watson Studio for sharing.

# %%
address = 'Appanoose County, IA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7455904 -92.8649061

# %%
radius = 10000

url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=2EN2GRB4CYL53K55NJI4X0LZM0JOGP2PIFFEFFPSDGTIMNR3&client_secret=M3GVSBQ3DDNWAZIF1SL0FVQYBNUWQZBLYQBOG1XOAYXLNBMT&v=20180604&ll=40.7455904,-92.8649061&radius=10000&limit=30'

# %%
results = requests.get(url2).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fb951e5f80c210a28e89ff8'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Centerville',
#   'headerFullLocation': 'Centerville',
#   'headerLocationGranularity': 'city',
#   'totalResults': 28,
#   'suggestedBounds': {'ne': {'lat': 40.83559049000009,
#     'lng': -92.74633397106352},
#    'sw': {'lat': 40.65559030999991, 'lng': -92.98347822893648}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc119f4abf495217890c093',
#        'name': "George & Nick's",
#        'location': {'address': '111 E Van Buren St',
#         'lat': 40.734908318428914,
#         'lng': -92.87385457137748,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.734908318428914,
#           'lng': -92.87385457137748}],
#         'distance': 1408,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['111 E Van Buren St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc119f4abf495217890c093-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc36972c844721e5c14e301',
#        'name': 'The Continental Hotel',
#        'location': {'address': '217 N 13th St',
#         'lat': 40.73407705750076,
#         'lng': -92.87310380962967,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73407705750076,
#           'lng': -92.87310380962967}],
#         'distance': 1456,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['217 N 13th St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '522476262'}},
#       'referralId': 'e-0-4cc36972c844721e5c14e301-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d869f7661676dcbc55fa4e4',
#        'name': 'Double R Dairy Bar',
#        'location': {'address': '701-1017 E Maple St',
#         'lat': 40.73274649,
#         'lng': -92.86738472,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73274649,
#           'lng': -92.86738472}],
#         'distance': 1444,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['701-1017 E Maple St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d869f7661676dcbc55fa4e4-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be700312457a5939666ad15',
#        'name': 'Hy-Vee',
#        'location': {'address': '609 N 18th St',
#         'lat': 40.737573,
#         'lng': -92.866358,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.737573,
#           'lng': -92.866358}],
#         'distance': 900,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['609 N 18th St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '553922908'}},
#       'referralId': 'e-0-4be700312457a5939666ad15-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ced2ff5840a9eb0a9f69f13',
#        'name': "Casey's General Store",
#        'location': {'address': '708 E Van Buren St',
#         'lat': 40.734607062458046,
#         'lng': -92.86770959317928,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.734607062458046,
#           'lng': -92.86770959317928}],
#         'distance': 1245,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['708 E Van Buren St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ced2ff5840a9eb0a9f69f13-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7c35d89efda143752385e2',
#        'name': 'Dollar General',
#        'location': {'address': '1006 N 18th St',
#         'lat': 40.74266052246094,
#         'lng': -92.86894226074219,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74266052246094,
#           'lng': -92.86894226074219}],
#         'distance': 471,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['1006 N 18th St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#          'name': 'Discount Store',
#          'pluralName': 'Discount Stores',
#          'shortName': 'Discount Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c7c35d89efda143752385e2-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b0d65c7112c6c002cfb4b9e',
#        'name': "Casey's General Store",
#        'location': {'address': '401 W Maple St',
#         'lat': 40.7326981,
#         'lng': -92.8764696,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7326981,
#           'lng': -92.8764696}],
#         'distance': 1735,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['401 W Maple St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b0d65c7112c6c002cfb4b9e-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c94f63258d4b60c11942d29',
#        'name': 'Subway',
#        'location': {'address': '1015A N 18th St Ste A',
#         'lat': 40.74383591153046,
#         'lng': -92.86635148783,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74383591153046,
#           'lng': -92.86635148783}],
#         'distance': 230,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['1015A N 18th St Ste A',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c94f63258d4b60c11942d29-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c79931abd346dcbedfef5ef',
#        'name': 'SONIC Drive In',
#        'location': {'address': '1030 N 18th St',
#         'lat': 40.7439934084707,
#         'lng': -92.8684765181969,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7439934084707,
#           'lng': -92.8684765181969}],
#         'distance': 349,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['1030 N 18th St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c79931abd346dcbedfef5ef-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9358dfb053b60c21658ccb',
#        'name': 'United States Postal Service',
#        'location': {'address': '300 N 10th St',
#         'lat': 40.73446070723197,
#         'lng': -92.87686966359615,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73446070723197,
#           'lng': -92.87686966359615}],
#         'distance': 1597,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['300 N 10th St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d172941735',
#          'name': 'Post Office',
#          'pluralName': 'Post Offices',
#          'shortName': 'Post Office',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9358dfb053b60c21658ccb-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e2b7b52227197a112dae7c9',
#        'name': "Hardee's",
#        'location': {'address': '100 E Maple St',
#         'lat': 40.731986328129146,
#         'lng': -92.87378909138431,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.731986328129146,
#           'lng': -92.87378909138431}],
#         'distance': 1689,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['100 E Maple St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e2b7b52227197a112dae7c9-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5ffa593a3703bb4310e406',
#        'name': 'Pizza Hut',
#        'location': {'address': '1012 N 18th St',
#         'lat': 40.74306881411465,
#         'lng': -92.86839455366135,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74306881411465,
#           'lng': -92.86839455366135}],
#         'distance': 406,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['1012 N 18th St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5ffa593a3703bb4310e406-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7d6155d461a14357fb7cf5',
#        'name': 'Shell',
#        'location': {'address': '102 Drake Ave',
#         'lat': 40.73221852,
#         'lng': -92.87292321,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73221852,
#           'lng': -92.87292321}],
#         'distance': 1634,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['102 Drake Ave',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '591942359'}},
#       'referralId': 'e-0-4c7d6155d461a14357fb7cf5-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4e182dbd4101d0d7a210e0',
#        'name': 'KFC',
#        'location': {'address': '306 E Maple St',
#         'lat': 40.73228608671931,
#         'lng': -92.8719501312828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73228608671931,
#           'lng': -92.8719501312828}],
#         'distance': 1595,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['306 E Maple St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1079389',
#         'url': 'https://www.grubhub.com/restaurant/kfc-306-e-maple-st-centerville/1079389?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1079389',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e4e182dbd4101d0d7a210e0-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e3478ac483bf3839a24a160',
#        'name': 'Taco Bell',
#        'location': {'address': '306 E Maple St',
#         'lat': 40.732322460044344,
#         'lng': -92.87184887827227,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.732322460044344,
#           'lng': -92.87184887827227}],
#         'distance': 1588,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['306 E Maple St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e3478ac483bf3839a24a160-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbe801b30c99c746af05311',
#        'name': "McDonald's",
#        'location': {'address': '1000 N 18th St',
#         'lat': 40.742158301701785,
#         'lng': -92.86882027052343,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.742158301701785,
#           'lng': -92.86882027052343}],
#         'distance': 504,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['1000 N 18th St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbe801b30c99c746af05311-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f32bef919836c91c7f5f4ba',
#        'name': 'Fridley - Cinema 4',
#        'location': {'address': '1013 N 18th St',
#         'lat': 40.7435188293457,
#         'lng': -92.86729431152344,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7435188293457,
#           'lng': -92.86729431152344}],
#         'distance': 306,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['1013 N 18th St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4d4b7105d754a06376d81259',
#          'name': 'Nightlife Spot',
#          'pluralName': 'Nightlife Spots',
#          'shortName': 'Nightlife',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f32bef919836c91c7f5f4ba-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd441a7d4c0e6b33e382b9e',
#        'name': 'Jing Jing',
#        'location': {'address': '717 N 18th St',
#         'lat': 40.73990084511409,
#         'lng': -92.8676300580547,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73990084511409,
#           'lng': -92.8676300580547}],
#         'distance': 673,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['717 N 18th St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd441a7d4c0e6b33e382b9e-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '515732eee4b0715456fcad86',
#        'name': 'Caseys',
#        'location': {'lat': 40.734599,
#         'lng': -92.867668,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.734599,
#           'lng': -92.867668}],
#         'distance': 1245,
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['Centerville, IA', 'United States']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-515732eee4b0715456fcad86-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f3239b619836c91c7c2868d',
#        'name': "George and Nick's Pizza and Steak",
#        'location': {'address': '107 E Van Buren St',
#         'lat': 40.735006,
#         'lng': -92.874019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.735006,
#           'lng': -92.874019}],
#         'distance': 1406,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['107 E Van Buren St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f3239b619836c91c7c2868d-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da0979b6fd25481e794629b',
#        'name': 'Fareway',
#        'location': {'address': '305 S 18th St',
#         'lat': 40.73119192391431,
#         'lng': -92.86695729686429,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73119192391431,
#           'lng': -92.86695729686429}],
#         'distance': 1612,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['305 S 18th St',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da0979b6fd25481e794629b-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50795e70e4b02a5a825e8ba4',
#        'name': 'High Point Dairy',
#        'location': {'lat': 40.765049,
#         'lng': -92.857614,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.765049,
#           'lng': -92.857614}],
#         'distance': 2251,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['Centerville, IA 52544', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d15b941735',
#          'name': 'Farm',
#          'pluralName': 'Farms',
#          'shortName': 'Farm',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/farm_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50795e70e4b02a5a825e8ba4-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fcd0023e4b07c4ac09951f6',
#        'name': 'Walmart Supercenter',
#        'location': {'address': '23148 Hwy 5',
#         'lat': 40.70919222,
#         'lng': -92.86648042,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70919222,
#           'lng': -92.86648042}],
#         'distance': 4053,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['23148 Hwy 5',
#          'Centerville, IA 52544',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b42',
#          'name': 'Big Box Store',
#          'pluralName': 'Big Box Stores',
#          'shortName': 'Big Box Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fcd0023e4b07c4ac09951f6-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e10eee67d8b4d5613d6aa9a',
#        'name': 'Tackle This',
#        'location': {'address': '400 Main St',
#         'crossStreet': 'at Walnut St',
#         'lat': 40.80070236666667,
#         'lng': -92.8875962,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.80070236666667,
#           'lng': -92.8875962}],
#         'distance': 6426,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Rathbun',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['400 Main St (at Walnut St)',
#          'Rathbun, IA 52544',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e10eee67d8b4d5613d6aa9a-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e3c4c1b7d8b0e96105a17f7',
#        'name': 'Numa Station',
#        'location': {'address': '99 Main St',
#         'lat': 40.80073928833008,
#         'lng': -92.89080810546875,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.80073928833008,
#           'lng': -92.89080810546875}],
#         'distance': 6515,
#         'postalCode': '52544',
#         'cc': 'US',
#         'city': 'Numa',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['99 Main St', 'Numa, IA 52544', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e3c4c1b7d8b0e96105a17f7-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f820f3be4b01cf82410120b',
#        'name': 'Rathbun Dam',
#        'location': {'lat': 40.82236183568094,
#         'lng': -92.89264154088147,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.82236183568094,
#           'lng': -92.89264154088147}],
#         'distance': 8860,
#         'postalCode': '52574',
#         'cc': 'US',
#         'city': 'Mystic',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['Mystic, IA 52574', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d161941735',
#          'name': 'Lake',
#          'pluralName': 'Lakes',
#          'shortName': 'Lake',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f820f3be4b01cf82410120b-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f5fa458e4b04ddc39b4a9cf',
#        'name': 'rathbun fish hatchery',
#        'location': {'lat': 40.82541214464573,
#         'lng': -92.87758337234966,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.82541214464573,
#           'lng': -92.87758337234966}],
#         'distance': 8949,
#         'cc': 'US',
#         'state': 'Iowa',
#         'country': 'United States',
#         'formattedAddress': ['Iowa', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d161941735',
#          'name': 'Lake',
#          'pluralName': 'Lakes',
#          'shortName': 'Lake',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f5fa458e4b04ddc39b4a9cf-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '572f6639498eb4ab4e5f17eb',
#        'name': 'Hardwoods Hustle',
#        'location': {'lat': 40.722113,
#         'lng': -92.754682,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.722113,
#           'lng': -92.754682}],
#         'distance': 9657,
#         'cc': 'US',
#         'city': 'Centerville',
#         'state': 'IA',
#         'country': 'United States',
#         'formattedAddress': ['Centerville, IA', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f4931735',
#          'name': 'Racetrack',
#          'pluralName': 'Racetracks',
#          'shortName': 'Racetrack',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/racetrack_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-572f6639498eb4ab4e5f17eb-27'}]}]}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                     name      categories        lat        lng
# 0        George & Nick's      Steakhouse  40.734908 -92.873855
# 1  The Continental Hotel           Hotel  40.734077 -92.873104
# 2     Double R Dairy Bar  Ice Cream Shop  40.732746 -92.867385
# 3                 Hy-Vee   Grocery Store  40.737573 -92.866358
# 4  Casey's General Store     Pizza Place  40.734607 -92.867710

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 28 venues were returned by Foursquare.
